# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('IT Salary Survey EU  2020.csv')
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
df.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
# rows and columns
df.shape
# Out:
# (1253, 23)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %%
# Renaming columns
df.columns = ['Timestamp', 'Age', 'Gender', 'City', 'Position',
       'experience(years)', 'Germany_experience(Years)',
       'Seniority_level', 'main_technology','Other_technologies','Yearly_salary',
       'bonus+stocks', 'salary_one_year_ago','bonus+stocks_one_year_ago','Number_of_vacation_days','Employment-status', 'Сontract-duration',
             'Main language at work', 'Company_size', 'Company_type','lost_job_due_to_covid','shorter_working_week(Kurzarbeit)hr/week','additional_monetary_support'
    
]

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position', 'experience(years)',
#        'Germany_experience(Years)', 'Seniority_level', 'main_technology',
#        'Other_technologies', 'Yearly_salary', 'bonus+stocks',
#        'salary_one_year_ago', 'bonus+stocks_one_year_ago',
#        'Number_of_vacation_days', 'Employment-status', 'Сontract-duration',
#        'Main language at work', 'Company_size', 'Company_type',
#        'lost_job_due_to_covid', 'shorter_working_week(Kurzarbeit)hr/week',
#        'additional_monetary_support'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age  Yearly_salary  salary_one_year_ago  \
# count  1226.000000   1.253000e+03         8.850000e+02
# mean     32.509788   8.027904e+07         6.322459e+05
# std       5.663804   2.825061e+09         1.680508e+07
# min      20.000000   1.000100e+04         1.100000e+04
# 25%      29.000000   5.880000e+04         5.500000e+04
# 50%      32.000000   7.000000e+04         6.500000e+04
# 75%      35.000000   8.000000e+04         7.500000e+04
# max      69.000000   1.000000e+11         5.000000e+08
#
#        shorter_working_week(Kurzarbeit)hr/week
# count                               373.000000
# mean                                 12.967828
# std                                  15.275174
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                  30.000000
# max                                  40.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Timestamp                                1253 non-null   object
#  1   Age                                      1226 non-null   float64
#  2   Gender                                   1243 non-null   object
#  3   City                                     1253 non-null   object
#  4   Position                                 1247 non-null   object
#  5   experience(years)                        1237 non-null   object
#  6   Germany_experience(Years)                1221 non-null   object
#  7   Seniority_level                          1241 non-null   object
#  8   main_technology                          1126 non-null   object
#  9   Other_technologies                       1096 non-null   object
# ...

# %%
# finding null values
df.isna().sum()
# Out:
# Timestamp                                    0
# Age                                         27
# Gender                                      10
# City                                         0
# Position                                     6
# experience(years)                           16
# Germany_experience(Years)                   32
# Seniority_level                             12
# main_technology                            127
# Other_technologies                         157
# Yearly_salary                                0
# bonus+stocks                               424
# salary_one_year_ago                        368
# bonus+stocks_one_year_ago                  639
# Number_of_vacation_days                     68
# Employment-status                           17
# Сontract-duration                           29
# Main language at work                       16
# Company_size                                18
# Company_type                                25
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# dropping null values
df1 = df.dropna(subset=['Age', 'Gender','Position','experience(years)','Germany_experience(Years)','Number_of_vacation_days','Seniority_level','Employment-status',
                      'Сontract-duration','Main language at work','Company_size','Company_type','lost_job_due_to_covid' ])
# df1 = df.dropna()
df1.isna().sum()
# Out:
# Timestamp                                    0
# Age                                          0
# Gender                                       0
# City                                         0
# Position                                     0
# experience(years)                            0
# Germany_experience(Years)                    0
# Seniority_level                              0
# main_technology                             92
# Other_technologies                         128
# Yearly_salary                                0
# bonus+stocks                               345
# salary_one_year_ago                        276
# bonus+stocks_one_year_ago                  527
# Number_of_vacation_days                      0
# Employment-status                            0
# Сontract-duration                            0
# Main language at work                        0
# Company_size                                 0
# Company_type                                 0
# ...

# %%
df1.shape
# Out:
# (1099, 23)

# %%
df2 = df1.dropna(axis=1)
df2.shape
# Out:
# (1099, 16)

# %%
df2.isna().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# City                         0
# Position                     0
# experience(years)            0
# Germany_experience(Years)    0
# Seniority_level              0
# Yearly_salary                0
# Number_of_vacation_days      0
# Employment-status            0
# Сontract-duration            0
# Main language at work        0
# Company_size                 0
# Company_type                 0
# lost_job_due_to_covid        0
# dtype: int64

# %%
df2.Gender.value_counts().plot(kind='bar')
plt.title('value count of Gender')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.show()

# %%
df2.City.value_counts()
# Out:
# Berlin               608
# Munich               217
# Frankfurt             37
# Hamburg               31
# Stuttgart             18
#                     ...
# Ulm                    1
# Bölingen               1
# Tampere (Finland)      1
# Minsk                  1
# Saarbrücken            1
# Name: City, Length: 104, dtype: int64

# %%
df2.Seniority_level.value_counts()
# Out:
# Senior                                       500
# Middle                                       327
# Lead                                         147
# Junior                                        70
# Head                                          39
# Principal                                      2
# C-level executive manager                      1
# Working Student                                1
# C-Level                                        1
# no idea, there are no ranges in the firm       1
# Student                                        1
# intern                                         1
# Director                                       1
# Key                                            1
# No level                                       1
# CTO                                            1
# Work Center Manager                            1
# VP                                             1
# No level                                       1
# ...

# %%
df2.Position.value_counts()
# Out:
# Software Engineer            393
# Backend Developer            174
# Data Scientist               110
# Frontend Developer            89
# QA Engineer                   71
#                             ...
# Testautomation                 1
# Recruiter                      1
# DBA                            1
# DB developer/Data analyst      1
# IT Operations Manager          1
# Name: Position, Length: 148, dtype: int64

# %%
df2
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                     Position experience(years)  \
# 0                          Software Engineer                 5
# 1                          Backend Developer                 7
# 2                          Software Engineer                12
# 3                         Frontend Developer                 4
# ...
